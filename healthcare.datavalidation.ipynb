# %%
#import pandas library
import pandas as pd

# %%
#checking the version of pandas library installed
print(pd.__version__)
# Out:
# 2.2.2

# %%
#uploading a csv file in python
df = pd.read_csv("C:/Users/khush_8qg3d62/Downloads/heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
#type of data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#length of dataset
len(df)
# Out:
# 253680

# %%
df.shape
# Out:
# (253680, 22)

# %%
df.head()
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                     0       1         1          1   40       1       0
# 1                     0       0         0          0   25       1       0
# 2                     0       1         1          1   28       0       0
# 3                     0       1         0          1   27       0       0
# 4                     0       1         1          1   24       0       0
#
#    Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0         0             0       0  ...              1            0        5
# 1         0             1       0  ...              0            1        3
# 2         0             0       1  ...              1            1        5
# 3         0             1       1  ...              1            0        2
# 4         0             1       1  ...              1            0        2
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# ...

# %%
#listing maximum columns and rows which are not visible in previous set
pd.set_option('display.max.columns',None)
pd.set_option('display.precision',2)

# %%
#last five rows of dataset
df.tail()
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 253675                     0       1         1          1   45       0
# 253676                     0       1         1          1   18       0
# 253677                     0       0         0          1   28       0
# 253678                     0       1         0          1   23       0
# 253679                     1       1         1          1   25       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# 253675       0         0             0       1        1                  0
# 253676       0         2             0       0        0                  0
# 253677       0         0             1       1        0                  0
# 253678       0         0             0       1        1                  0
# 253679       0         2             1       1        0                  0
#
#         AnyHealthcare  NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  \
# ...

# %%
#gender count 
df["Sex"].value_counts()
# Out:
# Sex
# 0    141974
# 1    111706
# Name: count, dtype: int64

# %%
#list of age counts
df["Age"].value_counts()
# Out:
# Age
# 9     33244
# 10    32194
# 8     30832
# 7     26314
# 11    23533
# 6     19819
# 13    17363
# 5     16157
# 12    15980
# 4     13823
# 3     11123
# 2      7598
# 1      5700
# Name: count, dtype: int64

# %%
# Step 1: Convert categorical columns to 'category' dtype
categorical_cols = [
    'HeartDiseaseorAttack', 'HighBP', 'HighChol', 'CholCheck', 'Smoker', 'Stroke',
    'Diabetes', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
    'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'Age', 'Education', 'Income', 'GenHlth'
]
df[categorical_cols] = df[categorical_cols].astype('category')

# %%
#Check for duplicates
duplicates = df.duplicated().sum()

# %%
#Check for invalid BMI values
invalid_bmi = df[df['BMI'] <= 0].shape[0]

# %%
#describe the dataset
df.describe()
# Out:
#              BMI   MentHlth   PhysHlth
# count  253680.00  253680.00  253680.00
# mean       28.38       3.18       4.24
# std         6.61       7.41       8.72
# min        12.00       0.00       0.00
# 25%        24.00       0.00       0.00
# 50%        27.00       0.00       0.00
# 75%        31.00       2.00       3.00
# max        98.00      30.00      30.00

# %%
#Final data types and shape after conversion
df_info = df.info()
(df.dtypes, df.shape, duplicates, invalid_bmi)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  category
#  1   HighBP                253680 non-null  category
#  2   HighChol              253680 non-null  category
#  3   CholCheck             253680 non-null  category
#  4   BMI                   253680 non-null  int64
#  5   Smoker                253680 non-null  category
#  6   Stroke                253680 non-null  category
#  7   Diabetes              253680 non-null  category
#  8   PhysActivity          253680 non-null  category
#  9   Fruits                253680 non-null  category
#  10  Veggies               253680 non-null  category
#  11  HvyAlcoholConsump     253680 non-null  category
#  12  AnyHealthcare         253680 non-null  category
#  13  NoDocbcCost           253680 non-null  category
# ...

# %%
#import matplotlib to visualize dataset
import matplotlib.pyplot as plt

# %%
#import seaborn library
import seaborn as sns

# %%
# Get the counts for heart disease cases
heart_disease_counts = df['HeartDiseaseorAttack'].value_counts()

# Define labels
labels = ['No Heart Disease', 'Heart Disease']
colors = ['lightgreen', 'lightcoral']
# pie chart
plt.figure(figsize=(6, 6))
plt.pie(heart_disease_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Heart Disease Prevalence')
plt.axis('equal')  # Equal aspect ratio to ensure it's a perfect circle
plt.show()

# %%
#Distribution of hear disease cases
sns.countplot(x='HeartDiseaseorAttack', data = df)
plt.title('Distribution of heart disease cases')
plt.xlabel('Heart disease(0 = NO,1 = YES)')
plt.ylabel('Number of Individuals')
plt.show()

# %%
#Distribution by gender as count plot
plt.figure(figsize=(6, 4))
sns.countplot(x='Sex', data=df, hue='Sex', palette='pastel', legend=False)
plt.title('Distribution by Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.show()

# %%
#Distribution of gender represented in pie chart
df['Sex'].value_counts().plot.pie(
    labels = ['Female','Male'],
    autopct= '%1.1f%%',
    colors = ['lightpink', 'lightblue'],
    startangle = 90)
plt.title('Sex Distribution')
plt.ylabel('')
plt.show()

# %%
#visualization of count different age groups
age_map = {
    1:'18-24',2:'25-29',3:'30-34',4:'35-39',
    5:'40-44',6:'45-49',7:'50-54',8:'55-59',
    9:'60-64',10:'65-69',11:'70-74',12:'75-79',
    13:'80+'}
df["AgeGroup"] = df['Age'].map(age_map)

#Plot the distribution using countplot
plt.figure(figsize = (12,6))
sns.countplot(x = "AgeGroup",data = df,order = age_map.values(),hue='Age',palette = 'pastel',legend = False)
plt.title("Distribution of Age Groups")
plt.xlabel('Age Group')
plt.ylabel('count')
plt.tight_layout()
plt.show()

# %%
#Histogram plot of Physical health for past 30 days
plt.figure(figsize = (10,5))
sns.histplot(df["PhysHlth"],bins=31,kde = True,color = 'darkred')
plt.title("Distribution of physical health days(past 30 days")
plt.xlabel('Number of days with Poor Physcial Health')
plt.ylabel('frequency')
plt.tight_layout()
plt.show()

# %%
#Histogram plot of Mental health for past 30 days
plt.figure(figsize = (10,5))
sns.histplot(df["MentHlth"],bins = 31,kde = True,color = "orchid")
plt.title("Distribution of Mental Health from past 30 days")
plt.xlabel("Number of days with Poor Mental Health")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# List of health condition columns
health_conditions = ['HighBP', 'HighChol', 'Stroke', 'Diabetes', 'DiffWalk']

# Bar plots for each condition
fig, axes = plt.subplots(3, 2, figsize=(14, 12))
axes = axes.flatten()

for i, condition in enumerate(health_conditions):
    # Count 0s and 1s
    counts = df[condition].value_counts().sort_index()
    
    # Labels (0 = No, 1 = Yes)
    labels = ['No', 'Yes'] if len(counts) == 2 else counts.index.astype(str)
    
    # Bar plot
    axes[i].bar(labels, counts.values, color=['lightgreen', 'salmon'][:len(labels)])
    axes[i].set_title(f'Prevalence of {condition}')
    axes[i].set_ylabel('Count')

# Remove last subplot if the number is odd
if len(health_conditions) % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %%
# Count 0 (No) and 1 (Yes)
counts = df['HeartDiseaseorAttack'].value_counts().sort_index()
labels = ['No Heart Disease', 'Heart Disease']

# Bar chart
plt.bar(labels, counts, color=['lightgreen', 'salmon'])
plt.title('Distribution of Heart Disease Cases')
plt.xlabel('Heart Disease')
plt.ylabel('Number of People')
plt.show()
